# %% [markdown]
# # Full curriculum
#
# Clone the repo and run all nine parts (~10 min CPU).

# %%
# !git clone https://github.com/Rashal10/baremetal-llm.git
# %cd baremetal-llm
# !pip install -q -e ".[dev]"

# %%
# !python -m baremetal_llm.cli demo --cpu

# %%
# !python -m baremetal_llm.cli generate --checkpoint parts/part_2/runs/tiny-lm/model.pt --prompt "Attention is "
